# %%
import pandas as pd

# %%
#Data frame 

Employee_data = {
    "name": ["Bilal Kiani", "Afan Hafiz", "Shabbar Alam", "Saood Sheikh", "Junaid Kiani", "Abdul Qadar", "Saqib Sheikh", "Ameen Khan"],
    "age": [22, 23, 24, 21, 43, 44, 34, 50],
    "sallary": [20000, 30000, 40000, 50000, 45000, 60000, 43000, 50500],
    "performance_score": [50, 60, 89, 78, 68, 90, 95, 86]
}
df = pd.DataFrame(Employee_data)
print("Sample DataFrame: ")
print(df)
# Out:
# Sample DataFrame:
#            name  age  sallary  performance_score
# 0   Bilal Kiani   22    20000                 50
# 1    Afan Hafiz   23    30000                 60
# 2  Shabbar Alam   24    40000                 89
# 3  Saood Sheikh   21    50000                 78
# 4  Junaid Kiani   43    45000                 68
# 5   Abdul Qadar   44    60000                 90
# 6  Saqib Sheikh   34    43000                 95
# 7    Ameen Khan   50    50500                 86

# %%
# here we learn about: 
# how to select specific column in data set,
# to select columns we uses squre brackets
# Selecting Columns will return:
#       a series 
#       dataframe, multiple columns of data 
#syentex when selecting single column: 
#   column = df["column_name"]
#syntex when selectin multiple columns: 
#   column = df[["column1", "column2", ...]]

# %%
#        Selecting Columns 

# selecting single column:
print("Single column, name: ")
print(df["name"])

# selecting multiple columns 
print("\n \n Multiple columns, name, performance_score: ")
subset_dataframe = df[["name", "performance_score"]]
print(subset_dataframe)
# Out:
# Single column, name:
# 0     Bilal Kiani
# 1      Afan Hafiz
# 2    Shabbar Alam
# 3    Saood Sheikh
# 4    Junaid Kiani
# 5     Abdul Qadar
# 6    Saqib Sheikh
# 7      Ameen Khan
# Name: name, dtype: object
#
#
#  Multiple columns, name, performance_score:
#            name  performance_score
# 0   Bilal Kiani                 50
# 1    Afan Hafiz                 60
# 2  Shabbar Alam                 89
# 3  Saood Sheikh                 78
# 4  Junaid Kiani                 68
# 5   Abdul Qadar                 90
# 6  Saqib Sheikh                 95
# 7    Ameen Khan                 86
