# %%
import pandas as pd

# %%
# when we load data we dont know number of rows and cdataframe_columns, we dont know what type of data is in data set,  we dont know missing data in dataset
#for this pandas provides us a method    "info()" method
# this method displays:   
# No of rows and columns, 
# column names, data type,
# non null counts,
# memory usage of dataframe

# %%
df = pd.read_csv("StudentsPerformance.csv")
print("Displaying the info of Data Set: ")
print(df.info())
# Out:
# Displaying the info of Data Set:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
student = {
    "name": ["Bilal", "Afan", "Shabbar", "Saood"],
    "rollno": [103, 68, 105, 71],
    "cgpa": [3.21, 3.00, 2.5, 3.4]
}
dff = pd.DataFrame(student)
print("Info of Student Data: ")
print(dff.info())
# Out:
# Info of Student Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   rollno  4 non-null      int64
#  2   cgpa    4 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes
# None
